# %%
from tkinter import *
from PIL import Image,ImageTk
paris_house_root=Tk()
paris_house_root.title="Paris"
paris_house_root.geometry("1200x785")
paris_house_root.minsize(500,400)
paris_house_root.maxsize(800,600)
paris_house=Label(text="House Price Predectoin")
paris_house.pack()

image=Image.open(r"house.jpg")
photo=ImageTk.PhotoImage(image)
Paris_Label=Label(image=photo)
Paris_Label.pack()
import pandas as pd
house=pd.read_csv("ParisHousing.csv")
house
#scaling
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
X=house.iloc[:,:-1].values
y=house.iloc[:,-1].values
sc=MinMaxScaler()
X_sc=sc.fit_transform(X)
X_sc
#train test split
x_train,x_test,y_train,y_test=train_test_split(X_sc,y,random_state=42)
x_train
model7=LinearRegression()
model7.fit(x_train,y_train)
x_train_pred7=model7.predict(x_train)
x_train_pred7
print("Training Score:",r2_score(x_train_pred7,y_train))
x_test_pred7=model7.predict(x_test)
x_test_pred7
print("Testing score:",r2_score(x_test_pred7,y_test))

# squareMeters=float(input("Enter size in squaremeter of house:"))
# numberOfRooms=int(input("kindly enter number of room required:"))
# hasYard=int(input("Required hasyatd if yes than press 1,else no than press 0:"))
# hasPool=int(input("Required haspool if yes than press 1,else no than press 0:"))
# floors=int(input("Required numbers of floors:"))
# cityCode=int(input("Enter zip code:"))
# import numpy as np
# zip=np.array(house["cityCode"])
# if cityCode in zip:
#     pass
# else:
#     print("zip code is not avaliable:")
        
# cityPartRange=int(input("Enter Number citypartrange:"))
# numPrevOwners=int(input("Enter numbers of pre owners:"))
# made=int(input("made in year"))
# isNewBuilt=int(input("nedd newbuilt house if yes than press 1,else no than press 0:"))
# hasStormProtector=int(input("Required hasStormProtector  if yes than press 1,else no than press 0:"))
# basement=float(input("Enter size basment"))
# attic=float(input("Required  attic if yes than press 1,else no than press 0:"))
# garage=float(input("Enter size square meter  garge:"))
# hasStorageRoom=int(input("Required  hasStorageRoom if yes than press 1,else no than press 0:"))
# hasGuestRoom =int(input("Enter numbers of guest rooms required:"))
# sample=[[squareMeters,numberOfRooms,hasYard,hasPool,floors,cityCode,cityPartRange,numPrevOwners,made,isNewBuilt,hasStormProtector,basement,attic,garage,hasStorageRoom,hasGuestRoom ]]
# print(sample)
# len(sample[0])
# sample_sc=sc.transform(sample)
# sample_sc
# model7.predict(sample_sc)

paris_house_root.mainloop()
# Out:
# Training Score: 0.9999995597584086
# Testing score: 0.9999995799318491

# %%
house.corr()
# Out:
#                    squareMeters  numberOfRooms   hasYard   hasPool    floors  \
# squareMeters           1.000000       0.009573 -0.006650 -0.005594  0.001109
# numberOfRooms          0.009573       1.000000 -0.011240  0.017015  0.022244
# hasYard               -0.006650      -0.011240  1.000000  0.015514 -0.000883
# hasPool               -0.005594       0.017015  0.015514  1.000000 -0.004006
# floors                 0.001109       0.022244 -0.000883 -0.004006  1.000000
# cityCode              -0.001541       0.009040  0.006760  0.008072  0.002207
# cityPartRange          0.008758       0.008340  0.005023  0.014613 -0.004921
# numPrevOwners          0.016619       0.016766  0.004279 -0.006848  0.002463
# made                  -0.007207       0.003978  0.002214  0.001894  0.005022
# isNewBuilt            -0.010667      -0.002865 -0.008370  0.000188  0.002458
# hasStormProtector      0.007480      -0.001656 -0.007598 -0.001001 -0.008566
# ...

# %%
#  correlation into visualform using heatmap of seaborn
import seaborn as sn
import pandas as pd
sn.heatmap(house.corr())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 import pandas as pd
#       4 sn.heatmap(house.corr())
# ----> 5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
house['cityCode'].drop_duplicates()
# Out:
# 0        9373
# 1       39381
# 2       34457
# 3       27939
# 4       38045
#         ...
# 9995    73133
# 9996    34606
# 9997    80933
# 9998    55856
# 9999    18412
# Name: cityCode, Length: 9509, dtype: int64
